# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_columns', 100)

import matplotlib as plt
import seaborn as sns

# %matplotlib inline

sns.set()

# %%
train_data = pd.read_csv("../data/processed_data/train_processed.csv",index_col=0)
holdout_data = pd.read_csv("../data/processed_data/test_processed.csv",index_col=0)

# %%
holdout_data.head()
# Out:
#               LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# LotFrontage
#  0.462234    0.184371    -0.772552     0.391237  -0.340510     -1.113625
#  0.508284    0.519791    -0.063185     0.391237  -0.439565     -1.257229
#  0.185936    0.464374    -0.772552    -0.507284   0.848148      0.657493
#  0.370135   -0.024109    -0.063185     0.391237   0.881166      0.657493
# -1.241605   -0.654748     1.355551    -0.507284   0.683057      0.370284
#
#              MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# LotFrontage
#  0.462234     -0.567016    0.058675    0.558290  -0.661137    -0.384127
#  0.508284      0.036930    1.057516   -0.293025  -0.351705     0.629375
#  0.185936     -0.567016    0.767742   -0.293025  -0.963743    -0.279829
#  0.370135     -0.455174    0.352839   -0.293025  -0.538274    -0.284364
# -1.241605     -0.567016   -0.391353   -0.293025   1.038461     0.518275
#
# ...
