# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(palette="Spectral")

# %%
df = pd.read_csv("../stats.csv")

# %%
df = df.round(3)

# %%
df
# Out:
#         Algorithm  Log Ordinal  CPU     R2   RMSE       Override
# 0           Ridge   No     Yes   13  0.881 -0.165            NaN
# 1           Ridge  Yes     Yes    9  0.913 -0.106            NaN
# 2           Lasso   No     Yes   42  0.899 -0.147            NaN
# 3           Lasso  Yes     Yes    4  0.905 -0.111            NaN
# 4      ElasticNet   No     Yes   34  0.894 -0.143            NaN
# 5      ElasticNet  Yes     Yes    9  0.918 -0.103            NaN
# 6   BayesianRidge   No     Yes    4  0.893 -0.143            NaN
# 7   BayesianRidge  Yes     Yes    3  0.913 -0.106            NaN
# 8    RandomForest   No     Yes   77  0.850 -0.126            NaN
# 9    RandomForest  Yes     Yes  130  0.827 -0.113            NaN
# 10   RandomForest  Yes     Yes   84  0.879 -0.111  RMSE Override
# 11     ExtraTrees   No     Yes   86  0.866 -0.115            NaN
# 12     ExtraTrees  Yes     Yes   99  0.872 -0.109            NaN
# 13         Gboost   No     Yes  209  0.921 -0.109            NaN
# 14         Gboost  Yes     Yes  130  0.899 -0.114            NaN
# 15            XGB   No     Yes   67  0.902 -0.116            NaN
# 16            XGB  Yes     Yes   89  0.906 -0.110            NaN
# 17          Ridge   No      No   10  0.901 -0.129            NaN
# 18          Ridge  Yes      No   11  0.909 -0.108            NaN
# 19          Lasso   No      No   55  0.905 -0.125            NaN
# 20          Lasso  Yes      No    4  0.897 -0.116            NaN
# 21     ElasticNet   No      No   37  0.902 -0.128            NaN
# 22     ElasticNet  Yes      No   11  0.912 -0.107            NaN
# 23  BayesianRidge   No      No    6  0.901 -0.129            NaN
# 24  BayesianRidge  Yes      No    4  0.910 -0.108            NaN
# 25   RandomForest   No      No   63  0.849 -0.113            NaN
# 26   RandomForest  Yes      No  136  0.838 -0.113            NaN
# 27   RandomForest  Yes      No   66  0.873 -0.111            NaN
# 28     ExtraTrees   No      No   34  0.854 -0.120            NaN
# 29     ExtraTrees  Yes      No   88  0.871 -0.111            NaN
# 30         Gboost   No      No  222  0.914 -0.112            NaN
# 31         Gboost  Yes      No  121  0.902 -0.113            NaN
# 32            XGB   No      No  127  0.913 -0.112            NaN
# 33            XGB  Yes      No   75  0.902 -0.113            NaN

# %%
df.RMSE = df.RMSE * (-1)

# %%
df
# Out:
#         Algorithm  Log Ordinal  CPU     R2   RMSE       Override
# 0           Ridge   No     Yes   13  0.881  0.165            NaN
# 1           Ridge  Yes     Yes    9  0.913  0.106            NaN
# 2           Lasso   No     Yes   42  0.899  0.147            NaN
# 3           Lasso  Yes     Yes    4  0.905  0.111            NaN
# 4      ElasticNet   No     Yes   34  0.894  0.143            NaN
# 5      ElasticNet  Yes     Yes    9  0.918  0.103            NaN
# 6   BayesianRidge   No     Yes    4  0.893  0.143            NaN
# 7   BayesianRidge  Yes     Yes    3  0.913  0.106            NaN
# 8    RandomForest   No     Yes   77  0.850  0.126            NaN
# 9    RandomForest  Yes     Yes  130  0.827  0.113            NaN
# 10   RandomForest  Yes     Yes   84  0.879  0.111  RMSE Override
# 11     ExtraTrees   No     Yes   86  0.866  0.115            NaN
# 12     ExtraTrees  Yes     Yes   99  0.872  0.109            NaN
# 13         Gboost   No     Yes  209  0.921  0.109            NaN
# 14         Gboost  Yes     Yes  130  0.899  0.114            NaN
# 15            XGB   No     Yes   67  0.902  0.116            NaN
# 16            XGB  Yes     Yes   89  0.906  0.110            NaN
# 17          Ridge   No      No   10  0.901  0.129            NaN
# 18          Ridge  Yes      No   11  0.909  0.108            NaN
# 19          Lasso   No      No   55  0.905  0.125            NaN
# 20          Lasso  Yes      No    4  0.897  0.116            NaN
# 21     ElasticNet   No      No   37  0.902  0.128            NaN
# 22     ElasticNet  Yes      No   11  0.912  0.107            NaN
# 23  BayesianRidge   No      No    6  0.901  0.129            NaN
# 24  BayesianRidge  Yes      No    4  0.910  0.108            NaN
# 25   RandomForest   No      No   63  0.849  0.113            NaN
# 26   RandomForest  Yes      No  136  0.838  0.113            NaN
# 27   RandomForest  Yes      No   66  0.873  0.111            NaN
# 28     ExtraTrees   No      No   34  0.854  0.120            NaN
# 29     ExtraTrees  Yes      No   88  0.871  0.111            NaN
# 30         Gboost   No      No  222  0.914  0.112            NaN
# 31         Gboost  Yes      No  121  0.902  0.113            NaN
# 32            XGB   No      No  127  0.913  0.112            NaN
# 33            XGB  Yes      No   75  0.902  0.113            NaN

# %%
sns.set(palette="Spectral")
g = sns.catplot(data = df, x="Algorithm",y="CPU", col="Ordinal",col_wrap=1, hue="Log", kind="bar", height=6, )
g.set_xticklabels(rotation=30)

# %%
sns.set(palette="Pastel1")
g = sns.catplot(data = df, x="Algorithm",y="RMSE", col="Ordinal",col_wrap=1, hue="Log", kind="bar", height=6 )
g.set_xticklabels(rotation=30)
plt.ylim(0.08,0.165)
# Out:
# (0.08, 0.165)

# %%
sns.set(palette="Accent")
g = sns.catplot(data = df, x="Algorithm",y="R2", col="Ordinal",col_wrap=1, hue="Log", kind="bar", height=6 )
g.set_xticklabels(rotation=30)
plt.ylim(0.8,0.95)
# Out:
# (0.8, 0.95)
